# %% [markdown]
# # Stat function

# %%
import pandas as pd
import numpy as np


from scipy.stats import ttest_1samp
from scipy.stats import ttest_ind
from scipy.stats import norm
from scipy.stats import t

from random import randint

# %%
sample_1 =[randint(-10, 10) for i in range(20)]
sample_2 =[randint(-10, 10) for i in range(20)]
print(sample_1)
samples_qnty = int(input('Qnty of samples: '))
def samples_analysis(samples_qnty):
    
    if samples_qnty == 1:
        sample = map(int,input('input your sample (using comma as separator): ').split(','))
        sample = list(sample)
        print(sample)
    elif samples_qnty == 2:
        sample_1 = map(int,input('input your first sample (using comma as separator): ').split(','))
        sample_2 = map(int,input('input your second sample (using comma as separator): ').split(','))
        sample_1 = list(sample_1)
        sample_2 = list(sample_2)
    else:
        print('Only one or two samples!!')
# Out:
# [-10, -1, 8, -3, 7, -1, -4, 2, 7, 8, 2, 3, -2, -4, -8, 8, 10, -8, -8, 6]
# Qnty of samples: 5

# %%
samples_analysis(1)
# Out:
# 1
# input your sample: -10, -1, 8, -3, 7, -1, -4, 2, 7, 8, 2, 3, -2, -4, -8, 8, 10, -8, -8, 6
# [-10, -1, 8, -3, 7, -1, -4, 2, 7, 8, 2, 3, -2, -4, -8, 8, 10, -8, -8, 6]

# %%
lst1 = []
lst2 = []
for i in range(int(input())):
    a, b = map(int, input().split())
    lst1.append(a)
    lst2.append(b)
 
    print(f'lst 1: {lst1}')
    print(f'lst 2: {lst2}')
# Out:
# 4
# 5 6
# lst 1: [5]
# lst 2: [6]
# 5 6
# lst 1: [5, 5]
# lst 2: [6, 6]
# 7 8
# lst 1: [5, 5, 7]
# lst 2: [6, 6, 8]
# 9 0
# lst 1: [5, 5, 7, 9]
# lst 2: [6, 6, 8, 0]
